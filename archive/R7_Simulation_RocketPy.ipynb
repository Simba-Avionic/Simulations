# %%
from rocketpy import Environment, Rocket, HybridMotor, Flight, Fluid, CylindricalTank, MassFlowRateBasedTank, NoseCone, Tail
import yaml

# %%
with open("../dane_symulacji_rocketpy.yaml", 'r') as file:
    data = yaml.safe_load(file)

# %%
Env = Environment(
    latitude=data["Env"]["latitude"], 
    longitude=data["Env"]["longitude"], 
    elevation=data["Env"]["elevation"], 
)

# %%
import datetime
date_obj = datetime.date.fromisoformat(data["Flight"]["flight_day"])

result = (date_obj.year, date_obj.month, date_obj.day, 12)


Env.set_date(result)

# %%
Env.set_atmospheric_model(type="standard_atmosphere")

Env.all_info()
# Out:
# Gravity Details
#
# Acceleration of gravity at surface level:    9.7957 m/s²
# Acceleration of gravity at  80.000 km (ASL): 9.5554 m/s²
#
#
# Launch Site Details
#
# Launch Date: 2025-05-10 12:00:00 UTC
# Launch Site Latitude: 35.34723°
# Launch Site Longitude: -117.81006°
# Reference Datum: SIRGAS2000
# Launch Site UTM coordinates: 426393.10 W    3911851.79 N
# Launch Site UTM zone: 11S
# Launch Site Surface Elevation: 624.0 m
#
#
# Atmospheric Model Details
#
# Atmospheric Model Type: standard_atmosphere
# standard_atmosphere Maximum Height: 80.000 km
#
# Surface Atmospheric Conditions
#
# Surface Wind Speed: 0.00 m/s
# Surface Wind Direction: 0.00°
# Surface Wind Heading: 0.00°
# Surface Pressure: 940.67 hPa
# Surface Temperature: 284.10 K
# Surface Air Density: 1.153 kg/m³
# Surface Speed of Sound: 337.73 m/s
#
#
# Earth Model Details
#
# Earth Radius at Launch site: 6371.02 km
# Semi-major Axis: 6378.14 km
# Semi-minor Axis: 6356.75 km
# Flattening: 0.0034
#
#
#
# Gravity Model Plots
# Atmospheric Model Plots

# %%
# Define the fluids
oxidizer_liq=Fluid(name="nitrous oxide", density=790)
oxidizer_gas = Fluid(name="nitrous oxide", density=180)

# Define tank geometry
tank_shape = CylindricalTank(0.087, 0.700)

# Define tank
oxidizer_tank = MassFlowRateBasedTank(
    name="oxidizer_tank_r7",
    geometry=tank_shape,
    flux_time=4.9,
    initial_liquid_mass=9.87,
    initial_gas_mass=0.13,
    liquid_mass_flow_rate_in=0,
    liquid_mass_flow_rate_out=2,
    gas_mass_flow_rate_in=0,
    gas_mass_flow_rate_out=0,
    liquid=oxidizer_liq,
    gas=oxidizer_gas,
)

# %%
#Draw the tank
oxidizer_tank.draw()

# %%
oxidizer_tank.flux_time #returns the start and final times of the tank flux
# Out:
# (0, 4.9)

# %%
#Evolution of the Propellant Mass and 
oxidizer_tank.fluid_mass.plot()
#mass of the liquid as a function of time
oxidizer_tank.liquid_mass.plot()
#mass of the gas as a function of time
oxidizer_tank.gas_mass.plot()
#the Mass, liquid and gas flow rate
oxidizer_tank.net_mass_flow_rate.plot()
oxidizer_tank.net_liquid_flow_rate.plot()
oxidizer_tank.net_gas_flow_rate.plot()

# %%
#total fluid volume inside the tank as a function of time(sum of the liquid and gas volumes)
oxidizer_tank.fluid_volume.plot()
#the volume of the liquid as a function of time
oxidizer_tank.liquid_volume.plot()
#the volume of the gas as a function of time
oxidizer_tank.gas_volume.plot()

# %%
#liquid level as a function of time
oxidizer_tank.liquid_height.plot()

#gas level as a function of time
oxidizer_tank.gas_height.plot()

# %%
# Evolution of the Propellant center of mass position
oxidizer_tank.center_of_mass.plot()

oxidizer_tank.liquid_center_of_mass.plot()

oxidizer_tank.gas_center_of_mass.plot()

# %%
oxidizer_tank.inertia.plot()

oxidizer_tank.liquid_inertia.plot()

oxidizer_tank.gas_inertia.plot()

# %%
hybrid_motor = HybridMotor(
    thrust_source="SimLE_SimBa_R7_Rocket.eng",
    dry_mass=12.5,
    dry_inertia=data["Motor"]["dry_inertia"]
    center_of_dry_mass_position=0.58,
    burn_time=9,
    grain_number=1,
    grain_separation=0,
    grain_outer_radius=0.063,
    grain_initial_inner_radius=0.035,
    grain_initial_height=0.5,
    grain_density=947,
    nozzle_radius=0.0385,
    throat_radius=0.0185,
    grains_center_of_mass_position=0.5,
    coordinate_system_orientation="nozzle_to_combustion_chamber"
)

# %%
hybrid_motor.add_tank(
    tank=oxidizer_tank, position=1.42
)

# %%
hybrid_motor.all_info()
# Out:
# Nozzle Details
# Outlet Radius: 0.0385 m
# Throat Radius: 0.0185 m
# Outlet Area: 0.004657 m²
# Throat Area: 0.001075 m²
# Position: 0 m
#
# Grain Details
# Number of Grains: 1
# Grain Spacing: 0 m
# Grain Density: 947 kg/m3
# Grain Outer Radius: 0.063 m
# Grain Inner Radius: 0.035 m
# Grain Height: 0.5 m
# Grain Volume: 0.004 m3
# Grain Mass: 4.082 kg
#
# Motor Details
# Total Burning Time: 9 s
# Total Propellant Mass: 14.082 kg
# Structural Mass Ratio: 0.470
# Average Propellant Exhaust Velocity: 1447.277 m/s
# Average Thrust: 2264.477 N
# Maximum Thrust: 3675.248 N at 0.048 s after ignition.
# Total Impulse: 20380.293 Ns

# %%
R7 = Rocket(
    radius=0.087,
    mass=25,
    inertia=(0,0,0),
    power_off_drag="powerOffDragCurve.csv",
    power_on_drag="powerOnDragCurve.csv",
    center_of_mass_without_motor=1.94828,
    coordinate_system_orientation="tail_to_nose"
)

# %%
R7.add_motor(hybrid_motor, position=0)

# %%
buttons = R7.set_rail_buttons(
    upper_button_position=1.91455,
    lower_button_position=0.94021,
    angular_position=10,
)

buttons.all_info()
# Out:
# Identification of the AeroSurface:
# ----------------------------------
# Name: Rail Buttons
# Python Class: <class 'rocketpy.rocket.aero_surface.rail_buttons.RailButtons'>
#
# Geometric information of the RailButtons:
# -----------------------------------------
# Distance from one button to the other: 0.974 m
# Angular position of the buttons: 10.000 deg
#
# Lift information of the AeroSurface:
# -----------------------------------
# Center of Pressure position in local coordinates: (0.000, 0.000, 0.000)
# Lift coefficient derivative at Mach 0 and AoA 0: 0.000 1/rad

# %%
nose=R7.add_nose(
    length=0.750,
    kind="powerseries",
    bluffness=None,
    power=0.8,
    position=3.917)

nose.all_info()
# Out:
# Identification of the AeroSurface:
# ----------------------------------
# Name: Nose Cone
# Python Class: <class 'rocketpy.rocket.aero_surface.nose_cone.NoseCone'>
#
# Geometric information of NoseCone:
# ----------------------------------
# Length: 0.750 m
# Kind: powerseries
# Base radius: 0.087 m
# Reference rocket radius: 0.087 m
# Reference radius ratio: 1.000
#
# Lift information of the AeroSurface:
# -----------------------------------
# Center of Pressure position in local coordinates: (0.000, 0.000, 0.462)
# Lift coefficient derivative at Mach 0 and AoA 0: 2.000 1/rad

# %%
tail=R7.add_tail(
    top_radius=0.087,
    bottom_radius=0.072,
    length=0.095,
    position=0.095,
    
)

#tail.slant_length=0.0835
#tail.surface_area=0.0478365

tail.all_info()
# Out:
# Identification of the AeroSurface:
# ----------------------------------
# Name: Tail
# Python Class: <class 'rocketpy.rocket.aero_surface.tail.Tail'>
#
# Geometric information of the Tail:
# ----------------------------------
# Top radius: 0.087 m
# Bottom radius: 0.072 m
# Reference radius: 0.174 m
# Length: 0.095 m
# Slant length: 0.096 m
# Surface area: 0.048042 m²
#
# Lift information of the AeroSurface:
# -----------------------------------
# Center of Pressure position in local coordinates: (0.000, 0.000, 0.046)
# Lift coefficient derivative at Mach 0 and AoA 0: -0.630 1/rad

# %%
fins = R7.add_trapezoidal_fins(
    n=4,
    root_chord=0.204,
    tip_chord=0.136,
    span=0.1016,
    sweep_length=0.034,
    cant_angle=0,
    position=0.353,
)

fins.all_info()
# Out:
# Identification of the AeroSurface:
# ----------------------------------
# Name: Fins
# Python Class: <class 'rocketpy.rocket.aero_surface.fins.trapezoidal_fins.TrapezoidalFins'>
#
# Geometric information of the fin set:
# -------------------------------------
# Number of fins: 4
# Reference rocket radius: 0.087 m
# Tip chord: 0.136 m
# Root chord: 0.204 m
# Span: 0.102 m
# Cant angle: 0.000 ° or 0.000 rad
# Longitudinal section area: 0.017 m²
# Aspect ratio: 1.195
# Gamma_c: 0.000 m
# Mean aerodynamic chord: 0.047 m
#
# Roll information of the fin set:
# --------------------------------
# Geometric constant: 0.000 m
# Damping interference factor: 1.314 rad
# Forcing interference factor: 0.937 rad
#
# Lift information of the fin set:
# --------------------------------
# Lift interference factor: 1.461 m
# Center of Pressure position in local coordinates: (0.000, 0.000, 0.059)
# Lift Coefficient derivative (single fin) at Mach 0 and AoA 0: 1.260
# Lift Coefficient derivative (fin set) at Mach 0 and AoA 0: 3.682
# Roll parameters:
# Lift coefficient:

# %%
main = R7.add_parachute(
    name="main",
    cd_s=10.706,
    trigger=550,
    sampling_rate=100,
    lag=3,
    noise=(0, 0, 0),
)

drogue = R7.add_parachute(
    name="drogue",
    cd_s= 1.43,
    trigger="apogee",
    sampling_rate=100,
    lag=3,
    noise=(0, 0, 0),
)

main.all_info()
drogue.all_info()
# Out:
# Parachute Details
#
# Parachute Main with a cd_s of 10.7060 m2
# Ejection signal trigger: 550 m (AGL)
# Ejection system refresh rate: 100.000 Hz
# Time between ejection signal is triggered and the parachute is fully opened: 3.0 s
#
#
# Parachute Details
#
# Parachute Drogue with a cd_s of 1.4300 m2
# Ejection signal trigger: At Apogee
# Ejection system refresh rate: 100.000 Hz
# Time between ejection signal is triggered and the parachute is fully opened: 3.0 s

# %%
R7.all_info()
# Out:
# Inertia Details
#
# Rocket Mass: 25.000 kg (without motor)
# Rocket Dry Mass: 37.500 kg (with unloaded motor)
# Rocket Loaded Mass: 51.582 kg
# Rocket Structural Mass Ratio: 0.727
# Rocket Inertia (with unloaded motor) 11: 16.702 kg*m2
# Rocket Inertia (with unloaded motor) 22: 15.642 kg*m2
# Rocket Inertia (with unloaded motor) 33: 1.100 kg*m2
# Rocket Inertia (with unloaded motor) 12: 0.000 kg*m2
# Rocket Inertia (with unloaded motor) 13: 0.000 kg*m2
# Rocket Inertia (with unloaded motor) 23: 0.000 kg*m2
#
# Geometrical Parameters
#
# Rocket Maximum Radius: 0.087 m
# Rocket Frontal Area: 0.023779 m2
#
# Rocket Distances
# Rocket Center of Dry Mass - Center of Mass without Motor: 0.456 m
# Rocket Center of Dry Mass - Nozzle Exit: 1.492 m
# Rocket Center of Dry Mass - Center of Propellant Mass: 0.398 m
# Rocket Center of Mass - Rocket Loaded Center of Mass: 0.109 m
#
#
# Aerodynamics Lift Coefficient Derivatives
#
# Nose Cone Lift Coefficient Derivative: 2.000/rad
# Tail Lift Coefficient Derivative: -0.630/rad
# Fins Lift Coefficient Derivative: 3.682/rad
#
# Center of Pressure
#
# Nose Cone Center of Pressure position: 3.455 m
# Tail Center of Pressure position: 0.049 m
# Fins Center of Pressure position: 0.294 m
#
# Stability
#
# Center of Mass position (time=0): 1.383 m
# Center of Pressure position (time=0): 1.576 m
# Initial Static Margin (mach=0, time=0): -1.108 c
# Final Static Margin (mach=0, time=burn_out): -0.495 c
# Rocket Center of Mass (time=0) - Center of Pressure (mach=0): 0.193 m
#
#
# Parachute Details
#
# Parachute Main with a cd_s of 10.7060 m2
# Ejection signal trigger: 550 m (AGL)
# Ejection system refresh rate: 100.000 Hz
# Time between ejection signal is triggered and the parachute is fully opened: 3.0 s
#
#
# Parachute Details
#
# Parachute Drogue with a cd_s of 1.4300 m2
# Ejection signal trigger: At Apogee
# Ejection system refresh rate: 100.000 Hz
# Time between ejection signal is triggered and the parachute is fully opened: 3.0 s
#
#
# Rocket Draw
# ----------------------------------------
# Mass Plots
# ----------------------------------------
# Aerodynamics Plots
# ----------------------------------------
# Drag Plots
# --------------------
# Stability Plots
# --------------------
# Thrust-to-Weight Plot
# ----------------------------------------

# %%
test_flight = Flight(
  rocket=R7, environment=Env, rail_length=8,
)
# Out:
# capi_return is NULL
# Call-back cb_f_in_lsoda__user__routines failed.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 test_flight = Flight(
#       2   rocket=R7, environment=Env, rail_length=8,
#       3 )
#
# File ~/simba/Simulations/.venv/lib/python3.12/site-packages/rocketpy/simulation/flight.py:651, in Flight.__init__(self, rocket, environment, rail_length, inclination, heading, initial_solution, terminate_on_apogee, max_time, max_time_step, min_time_step, rtol, atol, time_overshoot, verbose, name, equations_of_motion, ode_solver)
#     648 self.flight_phases.add_phase(self.max_time)
#     650 # Simulate flight
# --> 651 self.__simulate(verbose)
#     653 # Initialize prints and plots objects
#     654 self.prints = _FlightPrints(self)
#
# File ~/simba/Simulations/.venv/lib/python3.12/site-packages/rocketpy/simulation/flight.py:815, in Flight.__simulate(self, verbose)
#     812 # Step through simulation
#     813 while phase.solver.status == "running":
#     814     # Execute solver step, log solution and function evaluations
# --> 815     phase.solver.step()
#     816     self.solution += [[phase.solver.t, *phase.solver.y]]
#     817     self.function_evaluations.append(phase.solver.nfev)
#
# File ~/simba/Simulations/.venv/lib/python3.12/site-packages/scipy/integrate/_ivp/base.py:197, in OdeSolver.step(self)
#     195 else:
#     196     t = self.t
# --> 197     success, message = self._step_impl()
#     199     if not success:
#     200         self.status = 'failed'
#
# File ~/simba/Simulations/.venv/lib/python3.12/site-packages/scipy/integrate/_ivp/lsoda.py:161, in LSODA._step_impl(self)
#     159 itask = integrator.call_args[2]
#     160 integrator.call_args[2] = 5
# --> 161 solver._y, solver.t = integrator.run(
#     162     solver.f, solver.jac or (lambda: None), solver._y, solver.t,
#     163     self.t_bound, solver.f_params, solver.jac_params)
#     164 integrator.call_args[2] = itask
#     166 if solver.successful():
#
# File ~/simba/Simulations/.venv/lib/python3.12/site-packages/scipy/integrate/_ode.py:1358, in lsoda.run(self, f, jac, y0, t0, t1, f_params, jac_params)
#    1354 args = [f, y0, t0, t1] + self.call_args[:-1] + \
#    1355        [jac, self.call_args[-1], f_params, 0, jac_params]
#    1357 with LSODA_LOCK:
# -> 1358     y1, t, istate = self.runner(*args)
#    1360 self.istate = istate
#    1361 if istate < 0:
#
# File ~/simba/Simulations/.venv/lib/python3.12/site-packages/scipy/integrate/_ivp/base.py:154, in OdeSolver.__init__.<locals>.fun(t, y)
#     152 def fun(t, y):
#     153     self.nfev += 1
# --> 154     return self.fun_single(t, y)
#
# File ~/simba/Simulations/.venv/lib/python3.12/site-packages/scipy/integrate/_ivp/base.py:23, in check_arguments.<locals>.fun_wrapped(t, y)
#      22 def fun_wrapped(t, y):
# ---> 23     return np.asarray(fun(t, y), dtype=dtype)
#
# File ~/simba/Simulations/.venv/lib/python3.12/site-packages/rocketpy/simulation/flight.py:1794, in Flight.u_dot_generalized(self, t, u, post_processing)
#    1792     drag_coeff = self.rocket.power_on_drag.get_value_opt(free_stream_mach)
#    1793 else:
# -> 1794     drag_coeff = self.rocket.power_off_drag.get_value_opt(free_stream_mach)
#    1795 R3 += -0.5 * rho * (free_stream_speed**2) * self.rocket.area * drag_coeff
#    1796 for air_brakes in self.rocket.air_brakes:
#
# File ~/simba/Simulations/.venv/lib/python3.12/site-packages/rocketpy/mathutils/function.py:553, in Function.__get_value_opt_1d(self, x)
#     550         self.get_value_opt = self.__get_value_opt_nd
#     551     return self
# --> 553 def __get_value_opt_1d(self, x):
#     554     """Evaluate the Function at a single point x. This method is used
#     555     when the Function is 1-D.
#     556
#    (...)    565         Value of the Function at the specified point.
#     566     """
#     567     # Retrieve general info
#
# KeyboardInterrupt:

# %%
test_flight.all_info()
# Out:
# Initial Conditions
#
# Initial time: 0.000 s
# Position - x: 0.00 m | y: 0.00 m | z: 624.00 m
# Velocity - Vx: 0.00 m/s | Vy: 0.00 m/s | Vz: 0.00 m/s
# Attitude (quaternions) - e0: 0.763 | e1: -0.056 | e2: 0.067 | e3: -0.640
# Euler Angles - Spin φ : 10.00° | Nutation θ: -10.00° | Precession ψ: -90.00°
# Angular Velocity - ω1: 0.00 rad/s | ω2: 0.00 rad/s | ω3: 0.00 rad/s
# Initial Stability Margin: -0.648 c
#
#
# Surface Wind Conditions
#
# Frontal Surface Wind Speed: 0.00 m/s
# Lateral Surface Wind Speed: 0.00 m/s
#
#
# Launch Rail
#
# Launch Rail Length: 8 m
# Launch Rail Inclination: 80.00°
# Launch Rail Heading: 90.00°
#
#
# Rail Departure State
#
# Rail Departure Time: 0.486 s
# Rail Departure Velocity: 25.372 m/s
# Rail Departure Stability Margin: -0.659 c
# Rail Departure Angle of Attack: 0.000°
# Rail Departure Thrust-Weight Ratio: 6.330
# Rail Departure Reynolds Number: 2.878e+05
#
#
# Burn out State
#
# Burn out time: 9.000 s
# Altitude at burn out: 2375.672 m (ASL) | 1751.672 m (AGL)
# Rocket speed at burn out: 311.640 m/s
# Freestream velocity at burn out: 311.640 m/s
# Mach Number at burn out: 0.943
# Kinetic energy at burn out: 1.831e+06 J
#
#
# Apogee State
#
# Apogee Time: 33.667 s
# Apogee Altitude: 5539.215 m (ASL) | 4915.215 m (AGL)
# Apogee Freestream Speed: 40.365 m/s
# Apogee X position: 1886.686 m
# Apogee Y position: -0.411 m
# Apogee latitude: 35.3472254°
# Apogee longitude: -117.7892624°
#
#
# Parachute Events
#
# Parachute: Drogue
# 	Ejection time: 33.670 s
# 	Inflation time: 36.670 s
# 	Freestream speed at inflation: 42.207 m/s
# 	Altitude at inflation: 5499.966 m (ASL) | 4915.215 m (AGL)
# Parachute: Main
# 	Ejection time: 215.900 s
# 	Inflation time: 218.900 s
# 	Freestream speed at inflation: 21.656 m/s
# 	Altitude at inflation: 1108.675 m (ASL) | 549.745 m (AGL)
#
#
# Impact Conditions
#
# Time of impact: 280.252 s
# X impact: 2102.132 m
# Y impact: -0.448 m
# Altitude impact: 624.000 m (ASL) | -0.000 m (AGL)
# Latitude: 35.3472246°
# Longitude: -117.7868869°
# Vertical velocity at impact: -7.717 m/s
# Number of parachutes triggered until impact: 2
#
#
# Stability Margin
#
# Initial Stability Margin: -0.648 c at 0.00 s
# Out of Rail Stability Margin: -0.659 c at 0.49 s
# Maximum Stability Margin: 0.194 c at 8.65 s
# Minimum Stability Margin: -0.662 c at 0.97 s
#
#
# Maximum Values
#
# Maximum Speed: 315.823 m/s at 8.08 s
# Maximum Mach Number: 0.952 Mach at 8.22 s
# Maximum Reynolds Number: 3.208e+06 at 7.57 s
# Maximum Dynamic Pressure: 4.998e+04 Pa at 7.77 s
# Maximum Acceleration During Motor Burn: 61.458 m/s² at 0.05 s
# Maximum Gs During Motor Burn: 6.267 g at 0.05 s
# Maximum Acceleration After Motor Burn: 6.286 m/s² at 8.91 s
# Maximum Gs After Motor Burn: 0.641 Gs at 8.91 s
# Maximum Stability Margin: 0.194 c at 8.65 s
# Maximum Upper Rail Button Normal Force: 0.000 N
# Maximum Upper Rail Button Shear Force: 0.000 N
# Maximum Lower Rail Button Normal Force: 0.000 N
# Maximum Lower Rail Button Shear Force: 0.000 N
#
#
# Numerical Integration Settings
#
# Maximum Allowed Flight Time: 600.00 s
# Maximum Allowed Time Step: inf s
# Minimum Allowed Time Step: 0.00e+00 s
# Relative Error Tolerance: 1e-06
# Absolute Error Tolerance: [0.001, 0.001, 0.001, 0.001, 0.001, 0.001, 1e-06, 1e-06, 1e-06, 1e-06, 0.001, 0.001, 0.001]
# Allow Event Overshoot: True
# Terminate Simulation on Apogee: False
# Number of Time Steps Used: 401
# Number of Derivative Functions Evaluation: 147
# Average Function Evaluations per Time Step: 0.367
#
#
#
# Trajectory 3d Plot
# Trajectory Kinematic Plots
# Angular Position Plots
# Path, Attitude and Lateral Attitude Angle plots
# Trajectory Angular Velocity and Acceleration Plots
# Aerodynamic Forces Plots
# Rail Buttons Forces Plots
# Trajectory Energy Plots
# Trajectory Fluid Mechanics Plots
# Trajectory Stability and Control Plots
# Rocket and Parachute Pressure Plots
# Parachute:  main
# Parachute:  drogue
